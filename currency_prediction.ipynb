# %%
# installing yahoo finance library
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in /Users/iliyask/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (0.2.43)
# Requirement already satisfied: pandas>=1.3.0 in /Users/iliyask/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in /Users/iliyask/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from yfinance) (1.25.2)
# Requirement already satisfied: requests>=2.31 in /Users/iliyask/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in /Users/iliyask/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /Users/iliyask/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from yfinance) (4.9.1)
# Requirement already satisfied: platformdirs>=2.0.0 in /Users/iliyask/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from yfinance) (2.5.2)
# Requirement already satisfied: pytz>=2022.5 in /Users/iliyask/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from yfinance) (2024.1)
# Requirement already satisfied: frozendict>=2.3.4 in /Users/iliyask/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from yfinance) (2.4.4)
# Requirement already satisfied: peewee>=3.16.2 in /Users/iliyask/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from yfinance) (3.17.6)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /Users/iliyask/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from yfinance) (4.11.1)
# Requirement already satisfied: html5lib>=1.1 in /Users/iliyask/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/iliyask/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.3.2.post1)
# Requirement already satisfied: six>=1.9 in /Users/iliyask/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /Users/iliyask/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/iliyask/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/iliyask/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from pandas>=1.3.0->yfinance) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/iliyask/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from requests>=2.31->yfinance) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/iliyask/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from requests>=2.31->yfinance) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/iliyask/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from requests>=2.31->yfinance) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/iliyask/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from requests>=2.31->yfinance) (2022.9.24)

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import preprocessing
import datetime
from operator import itemgetter
from sklearn.preprocessing import MinMaxScaler

# %%
# importing libraries
import yfinance as yf

# importing USD-JPY data
usd_jpy_df = yf.download('USDJPY=X', start='1996-10-30', end='2024-08-29')
usd_jpy_df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  Volume
# Date
# 1996-10-30  114.370003  114.480003  113.610001  114.180000  114.180000       0
# 1996-11-01  113.500000  113.500000  113.500000  113.500000  113.500000       0
# 1996-11-04  113.279999  113.980003  112.949997  113.879997  113.879997       0
# 1996-11-05  113.709999  114.330002  113.449997  114.250000  114.250000       0
# 1996-11-06  114.230003  114.680000  113.650002  113.949997  113.949997       0

# %%
# From here we can see that on average yen value was 111.5, and it was min 75 yen.73 per usd, highest was 161.2
usd_jpy_df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  Volume
# count  7218.000000  7218.000000  7218.000000  7218.000000  7218.000000  7218.0
# mean    111.594651   112.050878   111.095597   111.589815   111.589815     0.0
# std      16.040874    16.123239    15.955976    16.040775    16.040775     0.0
# min      75.750000    75.973999    75.570000    75.739998    75.739998     0.0
# 25%     104.322500   104.806999   103.900501   104.316002   104.316002     0.0
# 50%     110.992496   111.407001   110.586502   110.999500   110.999500     0.0
# 75%     119.856001   120.349998   119.297503   119.848000   119.848000     0.0
# max     161.621002   161.942001   161.300003   161.621002   161.621002     0.0

# %%
# We can see that there are no null values
usd_jpy_df.isnull().sum()
# Out:
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
usd_jpy_df['Close'].plot()
plt.ylabel('Yen/USD')
plt.title('Historical relationship between Yen/USD')
# Out:
# Text(0.5, 1.0, 'Historical relationship between Yen/USD')

# %%
usd_jpy_df
# Out:
#                   Open        High         Low       Close   Adj Close  Volume
# Date
# 1996-10-30  114.370003  114.480003  113.610001  114.180000  114.180000       0
# 1996-11-01  113.500000  113.500000  113.500000  113.500000  113.500000       0
# 1996-11-04  113.279999  113.980003  112.949997  113.879997  113.879997       0
# 1996-11-05  113.709999  114.330002  113.449997  114.250000  114.250000       0
# 1996-11-06  114.230003  114.680000  113.650002  113.949997  113.949997       0
# ...                ...         ...         ...         ...         ...     ...
# 2024-08-22  145.117996  146.470001  144.947998  145.117996  145.117996       0
# 2024-08-23  146.201996  146.473007  144.604996  146.201996  146.201996       0
# 2024-08-26  144.000000  144.578995  143.460007  144.000000  144.000000       0
# 2024-08-27  144.516006  145.153000  144.164993  144.516006  144.516006       0
# 2024-08-28  143.975006  145.024994  143.912003  143.975006  143.975006       0
#
# [7218 rows x 6 columns]

# %%
# Our data is not stationary
from statsmodels.tsa.stattools import adfuller

adfuller(usd_jpy_df['Close'])[1]  # p-value
# Out:
# 0.5522395324429307

# %%
fig, ax = plt.subplots(1,1, figsize=(8,3))
from statsmodels.graphics.tsaplots import plot_acf
plot_acf(usd_jpy_df['Close'], lags=25, ax=ax)
plt.show()

# %%
usd_jpy_df['Day_of_week'] = usd_jpy_df.index.dayofweek
usd_jpy_df['Month'] = usd_jpy_df.index.month
usd_jpy_df['Year'] = usd_jpy_df.index.year
usd_jpy_df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1996-10-30  114.370003  114.480003  113.610001  114.180000  114.180000
# 1996-11-01  113.500000  113.500000  113.500000  113.500000  113.500000
# 1996-11-04  113.279999  113.980003  112.949997  113.879997  113.879997
# 1996-11-05  113.709999  114.330002  113.449997  114.250000  114.250000
# 1996-11-06  114.230003  114.680000  113.650002  113.949997  113.949997
#
#             Volume  Day_of_week  Month  Year
# Date
# 1996-10-30       0            2     10  1996
# 1996-11-01       0            4     11  1996
# 1996-11-04       0            0     11  1996
# 1996-11-05       0            1     11  1996
# 1996-11-06       0            2     11  1996

# %%
#From here we can see
usd_jpy_df[usd_jpy_df['Year']==2024]['Close'].plot()
plt.title('Currency USD/Yen in 2024')
plt.ylabel('Yen/USD')
# Out:
# Text(0, 0.5, 'Yen/USD')

# %%
# Plotting Adj Close price against Month
plt.figure(figsize=(15,8))
plt.grid(True)
plt.title('USD to JPY')
sns.boxplot(x=usd_jpy_df['Month'], y=usd_jpy_df['Adj Close'])
plt.xlabel('Date', fontsize=12)
plt.ylabel('Adj Close', fontsize=12)
plt.show()

# %% [markdown]
# ACF and PACF Plot

# %%
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
import matplotlib.pyplot as plt

plt.rc("figure", figsize=(10,5))
plot_acf(usd_jpy_df['Adj Close'])
print()

# %% [markdown]
# We can see autocorrelation until 40 lag values

# %%
#Partial auto-correlation shows only few lag values are actually correlated.
plt.rc("figure", figsize=(10,5))
plot_pacf(usd_jpy_df['Adj Close'])
print()

# %% [markdown]
# 📙 4. Price forecasting¶

# %%
data = usd_jpy_df['Adj Close'].values
data
# Out:
# array([114.18000031, 113.5       , 113.87999725, ..., 144.        ,
#        144.51600647, 143.9750061 ])

# %%
data.shape
# Out:
# (7218,)

# %%
# Separate train and test data
train_length = int(len(data) * 0.9)
print('Train length: ', train_length)

train_data, test_data = data[:train_length], data[train_length:]
print('Shape of Train and Test data: ', len(train_data), len(test_data))
# Out:
# Train length:  6496
# Shape of Train and Test data:  6496 722

# %%
# split a univariate sequence into supervised learning [Input and Output]
from numpy import array
def split_sequence(sequence, n_steps):
    X, y = list(), list()
    for i in range(len(sequence)-1-n_steps):
        #sequence=10, n_steps=3
        end_ix = i + n_steps
        seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
        X.append(seq_x)
        y.append(seq_y)
    return array(X), array(y)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [105], line 1
# ----> 1 X
#
# NameError: name 'X' is not defined

# %%
lag = 3  # Empirically we have choosen
n_features = 1

# %%
print('Shape of train_X and train_y: ', train_X.shape, train_y.shape)
print('Shape of test_X and test_y: ', test_X.shape, test_y.shape)
# Out:
# Shape of train_X and train_y:  (6492, 3) (6492,)
# Shape of test_X and test_y:  (718, 3) (718,)

# %%
train_X = train_X.reshape((train_X.shape[0], train_X.shape[1], n_features))
test_X = test_X.reshape((test_X.shape[0], test_X.shape[1], n_features))

# %%
# New shape of train_X and test_X are :-
print('Shape of train_X and train_y: ', train_X.shape, train_y.shape)
print('Shape of test_X and test_y: ', test_X.shape, test_y.shape)
# Out:
# Shape of train_X and train_y:  (6492, 3, 1) (6492,)
# Shape of test_X and test_y:  (718, 3, 1) (718,)

# %%
#4.4 Define Model
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense

# %%
# define model
model = Sequential()
model.add(LSTM(16, activation='relu', return_sequences=False, input_shape=(lag, n_features)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 16)                1152
#
#  dense_2 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 1,169
# Trainable params: 1,169
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit model
history = model.fit(train_X, train_y, epochs = 25, batch_size=8, verbose=1, validation_split= 0.1)
# Out:
# Epoch 1/25
# 731/731 [==============================] - 1s 800us/step - loss: 882.4429 - val_loss: 0.3459
# Epoch 2/25
# 731/731 [==============================] - 0s 646us/step - loss: 0.9099 - val_loss: 0.3144
# Epoch 3/25
# 731/731 [==============================] - 0s 624us/step - loss: 0.8435 - val_loss: 0.2764
# Epoch 4/25
# 731/731 [==============================] - 0s 660us/step - loss: 0.7842 - val_loss: 0.2683
# Epoch 5/25
# 731/731 [==============================] - 0s 659us/step - loss: 0.7793 - val_loss: 0.2329
# Epoch 6/25
# 731/731 [==============================] - 0s 616us/step - loss: 0.7801 - val_loss: 0.2352
# Epoch 7/25
# 731/731 [==============================] - 0s 665us/step - loss: 0.7874 - val_loss: 0.2260
# Epoch 8/25
# 731/731 [==============================] - 0s 627us/step - loss: 0.8000 - val_loss: 0.2338
# Epoch 9/25
# 731/731 [==============================] - 0s 627us/step - loss: 0.8170 - val_loss: 0.3985
# Epoch 10/25
# 731/731 [==============================] - 0s 633us/step - loss: 0.8400 - val_loss: 0.2638
# Epoch 11/25
# 731/731 [==============================] - 0s 654us/step - loss: 0.8266 - val_loss: 0.2412
# Epoch 12/25
# 731/731 [==============================] - 0s 624us/step - loss: 0.8423 - val_loss: 0.5098
# Epoch 13/25
# 731/731 [==============================] - 0s 676us/step - loss: 0.8424 - val_loss: 0.2350
# Epoch 14/25
# 731/731 [==============================] - 0s 631us/step - loss: 0.8601 - val_loss: 0.6720
# Epoch 15/25
# 731/731 [==============================] - 1s 754us/step - loss: 0.8602 - val_loss: 0.3431
# Epoch 16/25
# 731/731 [==============================] - 1s 707us/step - loss: 0.8228 - val_loss: 0.3809
# Epoch 17/25
# 731/731 [==============================] - 0s 607us/step - loss: 0.8128 - val_loss: 0.3063
# Epoch 18/25
# 731/731 [==============================] - 0s 593us/step - loss: 0.8246 - val_loss: 0.2343
# Epoch 19/25
# 731/731 [==============================] - 0s 624us/step - loss: 0.8511 - val_loss: 0.2257
# Epoch 20/25
# 731/731 [==============================] - 0s 674us/step - loss: 0.7852 - val_loss: 1.2237
# Epoch 21/25
# 731/731 [==============================] - 1s 688us/step - loss: 0.8080 - val_loss: 0.2433
# Epoch 22/25
# 731/731 [==============================] - 0s 597us/step - loss: 0.8588 - val_loss: 0.2273
# Epoch 23/25
# 731/731 [==============================] - 0s 655us/step - loss: 0.7854 - val_loss: 0.3686
# Epoch 24/25
# 731/731 [==============================] - 0s 640us/step - loss: 0.8567 - val_loss: 0.2594
# Epoch 25/25
# 731/731 [==============================] - 0s 599us/step - loss: 0.8085 - val_loss: 0.2689

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
train_predict = model.predict(train_X)
test_predict = model.predict(test_X)

print('Shape of train and test predict: ', train_predict.shape, test_predict.shape)
# Out:
# 203/203 [==============================] - 0s 322us/step
# 23/23 [==============================] - 0s 405us/step
# Shape of train and test predict:  (6492, 1) (718, 1)

# %%
# root mean squared error or rmse
import math
from sklearn.metrics import mean_squared_error

def measure_rmse(actual, predicted):
    return math.sqrt(mean_squared_error(actual, predicted))

train_score = measure_rmse(train_y, train_predict)
test_score = measure_rmse(test_y, test_predict)

print('Train and Test RMSE: ', train_score, test_score)
# Out:
# Train and Test RMSE:  0.8158317298643689 1.018712282419259

# %%
plt.rc("figure", figsize=(14,8))
plt.rcParams.update({'font.size': 16})
plt.plot(test_y, label = 'Actual')
plt.plot(test_predict, label = 'Predicted')
plt.xlabel('Time [in days]')
plt.ylabel('INR price')
plt.title('Currency price (Yen/Usd) prediction using LSTM - Test data')
plt.legend()
plt.show()

# %%
import numpy as np

# Assuming your model is already trained and 'model' is available

# Get the last sequence from your test data
last_sequence = test_X[-1]

# Initialize an array to store predictions
future_predictions = []

# Predict the next 10 days
for _ in range(10):
    # Reshape the last sequence to match the input shape of your model
    current_sequence = last_sequence.reshape((1, last_sequence.shape[0], last_sequence.shape[1]))

    # Make a prediction
    next_day_prediction = model.predict(current_sequence)

    # Append the prediction to our results
    future_predictions.append(next_day_prediction[0, 0])

    # Update the sequence by removing the first element and adding the prediction
    last_sequence = np.roll(last_sequence, -1, axis=0)
    last_sequence[-1] = next_day_prediction

# Convert to numpy array
future_predictions = np.array(future_predictions)

print("Shape of future predictions:", future_predictions.shape)
print("Future predictions for the next 10 days:", future_predictions)
# Out:
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# Shape of future predictions: (10,)
# Future predictions for the next 10 days: [144.54887 145.01613 145.50786 146.00716 146.51292 147.02602 147.54655
#  148.0747  148.61066 149.1546 ]

# %%
future_predictions
# Out:
# array([144.54887, 145.01613, 145.50786, 146.00716, 146.51292, 147.02602,
#        147.54655, 148.0747 , 148.61066, 149.1546 ], dtype=float32)
